# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.ticker as mticker
import seaborn as sns
import requests
from prophet import Prophet
from sklearn.metrics import mean_squared_error
from datetime import datetime
sns.set_theme(style="darkgrid")

# %%
def api_req(url,params):
    response = requests.get(url, params=params)
    # Parse response
    data = response.json()['Data']['Data']
    df = pd.DataFrame(data)
    df['timestamp'] = pd.to_datetime(df['time'], unit='s')
    df = df.sort_values(by='timestamp',ascending=False)
    df.drop(df.head(1).index,inplace=True)
    return df

# %%
# Only run this cell if updating the model with new data
url = 'https://min-api.cryptocompare.com/data/v2/histoday'
params = {
    'api_key':'4f5cd6a090d066496f7a74d6a33ef6913ef96807d2d33f5c47e50f7b011bf2be',
    'fsym': 'BTC',
    'tsym': 'USD',
    'limit': 730 # Get data for the past year
}
df = api_req(url,params)
df.head()
# Out:
#            time      high       low      open  volumefrom      volumeto  \
# 729  1680480000  28494.64  27290.26  28186.76    52416.66  1.467725e+09
# 728  1680393600  28538.36  27880.95  28465.30    21016.25  5.925811e+08
# 727  1680307200  28810.95  28265.42  28477.29    19774.03  5.632994e+08
# 726  1680220800  28650.47  27541.23  28037.46    50916.39  1.436740e+09
# 725  1680134400  29172.90  27731.64  28355.87    63033.78  1.790022e+09
#
#         close conversionType conversionSymbol  timestamp
# 729  27810.08         direct                  2023-04-03
# 728  28186.76         direct                  2023-04-02
# 727  28465.30         direct                  2023-04-01
# 726  28477.29         direct                  2023-03-31
# 725  28037.46         direct                  2023-03-30

# %%
# Only run this cell if training from price data in csv file
df = pd.read_csv('btc-daily-price.csv')
df['timestamp'] = pd.to_datetime(df['timestamp'])
df
# Out:
#            time      high       low      open  volumefrom      volumeto  \
# 0    1680480000  28494.64  27290.26  28186.76    52416.66  1.467725e+09
# 1    1680393600  28538.36  27880.95  28465.30    21016.25  5.925811e+08
# 2    1680307200  28810.95  28265.42  28477.29    19774.03  5.632994e+08
# 3    1680220800  28650.47  27541.23  28037.46    50916.39  1.436740e+09
# 4    1680134400  29172.90  27731.64  28355.87    63033.78  1.790022e+09
# ..          ...       ...       ...       ...         ...           ...
# 725  1617840000  58150.23  55711.07  55951.98    25461.84  1.458096e+09
# 726  1617753600  58628.19  55467.58  58010.35    50347.59  2.855411e+09
# 727  1617667200  59464.31  57369.44  59119.56    26304.15  1.535666e+09
# 728  1617580800  59235.68  56833.44  58219.43    24696.26  1.439529e+09
# 729  1617494400  58493.73  56493.38  57074.97    19002.99  1.093080e+09
#
#         close conversionType  conversionSymbol  timestamp
# 0    27810.08         direct               NaN 2023-04-03
# 1    28186.76         direct               NaN 2023-04-02
# 2    28465.30         direct               NaN 2023-04-01
# 3    28477.29         direct               NaN 2023-03-31
# 4    28037.46         direct               NaN 2023-03-30
# ..        ...            ...               ...        ...
# 725  58084.46         direct               NaN 2021-04-08
# 726  55951.98         direct               NaN 2021-04-07
# 727  58010.35         direct               NaN 2021-04-06
# 728  59119.56         direct               NaN 2021-04-05
# 729  58219.43         direct               NaN 2021-04-04
#
# [730 rows x 10 columns]

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(df['timestamp'], df['close'])
# format the x axis as dates
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))

# set the tick locator to show ticks at the start of each month
ax.xaxis.set_major_locator(mdates.MonthLocator())

# set the tick labels to show only the month and year
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

# set the rotation of the tick labels
plt.xticks(rotation=45)
plt.show()

# %%
# clean data for modelling
df = df[['timestamp', 'close']]
df.columns = ['ds', 'y']
df = df.dropna()

# %%
df.head()
# Out:
#           ds         y
# 0 2023-04-03  27810.08
# 1 2023-04-02  28186.76
# 2 2023-04-01  28465.30
# 3 2023-03-31  28477.29
# 4 2023-03-30  28037.46

# %%
model = Prophet()
model.fit(df)
# Out:
# 18:38:30 - cmdstanpy - INFO - Chain [1] start processing
# 18:38:31 - cmdstanpy - INFO - Chain [1] done processing

# %%
predictions = model.predict(df)
predictions = predictions[['ds', 'yhat']].tail(len(df)).sort_values('ds',ascending=False)

# %%
mse = mean_squared_error(df['y'], predictions['yhat'])
print(mse)
# Out:
# 13219637.19075297

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(df['ds'], df['y'])
ax.plot(predictions['ds'], predictions['yhat'])
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend(['Actual', 'Predicted'])
plt.show()
